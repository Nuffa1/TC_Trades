# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime, timedelta
import time
from textblob import TextBlob

# %%
news_headline = "hello! We love dogs!"

text = TextBlob(news_headline)
print(text.sentiment)
# Out:
# Sentiment(polarity=0.625, subjectivity=0.6)

# %%
polarity_weight = 0.6
subjectivity_weight = 0.4

polarity_score = text.sentiment.polarity * 
subjectivity_score = text.sentiment.subjectivity

# %%
from newsapi import NewsApiClient

# You'll need an API key from newsapi.org
newsapi = NewsApiClient(api_key='d456db1f3c1f416fbb02353d85bcaddf')

# Get top headlines mentioning a stock
all_articles = newsapi.get_everything(q='stock market headlines',
                                      language='en',
                                      sort_by='relevancy')

for article in all_articles['articles']:
    print(f"Title: {article['title']}")
    print(f"Source: {article['source']['name']}")
    print(f"Link: {article['url']}")
    print("-" * 20)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from newsapi import NewsApiClient
#       3 # You'll need an API key from newsapi.org
#       4 newsapi = NewsApiClient(api_key='d456db1f3c1f416fbb02353d85bcaddf')
#
# ImportError: cannot import name 'NewsApiClient' from 'newsapi' (/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/newsapi/__init__.py)
